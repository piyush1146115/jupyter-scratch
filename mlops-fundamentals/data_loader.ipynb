# %%
import pandas as pd
import numpy as np
import json
import random
from datetime import datetime, timedelta

# %%
# Set random seed for reproducibility
np.random.seed(42)

# Number of records
num_records = 20000

# Generate random data
data = {
    "id": np.arange(1, num_records + 1),
    "name": [f"Name_{i}" for i in np.random.randint(1, 1000, num_records)],
    "age": np.random.randint(18, 80, num_records),
    "salary": np.random.choice([50000, 60000, 70000, None], num_records),
    "hire_date": [
        (datetime.now() - timedelta(days=random.randint(0, 3650))).strftime("%Y-%m-%d")
        if random.random() > 0.1 else None
        for _ in range(num_records)
    ],
    "profile": [
        json.dumps({
            "address": f"Street {random.randint(1, 100)}, City {random.randint(1, 50)}",
            "phone": f"{random.randint(1000000000, 9999999999)}",
            "email": f"email_{random.randint(1, 1000)}@example.com"
        })
        if random.random() > 0.1 else None
        for _ in range(num_records)
    ],
    "department": np.random.choice(["HR", "IT", "Finance", "Marketing", None], num_records),
    "bonus": [None if random.random() > 0.9 else random.randint(1000, 10000) for _ in range(num_records)]
}

# Create DataFrame
df = pd.DataFrame(data)

# Introduce some NaN values randomly
df.loc[np.random.choice(df.index, size=int(num_records * 0.05), replace=False), "age"] = np.nan
df.loc[np.random.choice(df.index, size=int(num_records * 0.1), replace=False), "salary"] = np.nan

# Save to CSV
df.to_csv("mock_data.csv", index=False)

# %%
# Step 1: Load data
print("Loading data...")
df = pd.read_csv("mock_data.csv")
# Out:
# Loading data...

# %%
# Step 2: Display first few rows
print("First few rows of the DataFrame")
print(df.head())
# Out:
# First few rows of the DataFrame
#    id      name   age   salary   hire_date  \
# 0   1  Name_103  77.0  60000.0  2020-01-22
# 1   2  Name_436  62.0  50000.0  2019-04-28
# 2   3  Name_861  61.0  60000.0  2019-02-24
# 3   4  Name_271  36.0  70000.0  2024-04-29
# 4   5  Name_107  78.0  60000.0  2022-11-13
#
#                                              profile department   bonus
# 0  {"address": "Street 66, City 35", "phone": "51...  Marketing  9055.0
# 1  {"address": "Street 16, City 4", "phone": "921...  Marketing     NaN
# 2  {"address": "Street 12, City 13", "phone": "90...         HR  7197.0
# 3  {"address": "Street 37, City 38", "phone": "58...        NaN  5642.0
# 4  {"address": "Street 29, City 19", "phone": "39...         IT  4211.0

# %%
# Step 3: Info of the DataFrame
print("Information about the DataFrame")
print(df.info())
# Out:
# Information about the DataFrame
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          20000 non-null  int64
#  1   name        20000 non-null  object
#  2   age         19000 non-null  float64
#  3   salary      13519 non-null  float64
#  4   hire_date   17970 non-null  object
#  5   profile     18049 non-null  object
#  6   department  16003 non-null  object
#  7   bonus       18010 non-null  float64
# dtypes: float64(3), int64(1), object(4)
# memory usage: 1.2+ MB
# None

# %%
# Step 4: Check for missing values
print("Missing values in the DataFrame")
print(df.isnull().sum())
# Out:
# Missing values in the DataFrame
# id               0
# name             0
# age           1000
# salary        6481
# hire_date     2030
# profile       1951
# department    3997
# bonus         1990
# dtype: int64

# %%
# Step 5: Statistical summary
print("Statistical summary of the DataFrame")
print(df.describe(include="all"))
# Out:
# Statistical summary of the DataFrame
#                   id      name           age        salary   hire_date  \
# count   20000.000000     20000  19000.000000  13519.000000       17970
# unique           NaN       999           NaN           NaN        3628
# top              NaN  Name_825           NaN           NaN  2016-12-18
# freq             NaN        37           NaN           NaN          14
# mean    10000.500000       NaN     48.444684  59962.275316         NaN
# std      5773.647028       NaN     17.892848   8200.588356         NaN
# min         1.000000       NaN     18.000000  50000.000000         NaN
# 25%      5000.750000       NaN     33.000000  50000.000000         NaN
# 50%     10000.500000       NaN     48.000000  60000.000000         NaN
# 75%     15000.250000       NaN     64.000000  70000.000000         NaN
# max     20000.000000       NaN     79.000000  70000.000000         NaN
#
#                                                   profile department  \
# count                                               18049      16003
# unique                                              18049          4
# top     {"address": "Street 66, City 35", "phone": "51...         IT
# freq                                                    1       4058
# mean                                                  NaN        NaN
# std                                                   NaN        NaN
# min                                                   NaN        NaN
# 25%                                                   NaN        NaN
# 50%                                                   NaN        NaN
# 75%                                                   NaN        NaN
# max                                                   NaN        NaN
#
#                bonus
# count   18010.000000
# unique           NaN
# top              NaN
# freq             NaN
# mean     5494.291283
# std      2592.091659
# min      1000.000000
# 25%      3248.000000
# 50%      5483.000000
# 75%      7732.000000
# max     10000.000000

# %%
print("Unique values in department column")
print(df["department"].unique())
# Out:
# Unique values in department column
# ['Marketing' 'HR' nan 'IT' 'Finance']
